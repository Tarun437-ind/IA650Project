# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MLfinal.csv')
df
# Out:
#           STATION                              NAME  LATITUDE  LONGITUDE  \
# 0     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 1     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 2     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 3     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 4     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# ...           ...                               ...       ...        ...
# 2276  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 2277  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 2278  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 2279  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
# 2280  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915   -73.7639
#
#       ELEVATION        DATE   AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  \
# ...
